# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the population data

# %%
population_data=pd.read_csv("/home/dineshkumardavanam/Downloads/Integrated Household Survey.csv")

# %% [markdown]
# # Reading the Water data

# %%
water_data=pd.read_csv("/home/dineshkumardavanam/Downloads/Water supply.csv")

# %%
population_data
# Out:
#          Districts  Households  Total Population  Scheduled Castes  \
# 0         ADILABAD      202954            743983            112912
# 1        BHADRADRI      325055           1069332            159831
# 2        HYDERABAD     1049686           3979372            439097
# 3         JAGTIAL       317981           1019045            178760
# 4         JANGAON       181878            625537            138994
# 5     JAYASHANKAR       231133            723299            148025
# 6       JOGULAMBA       144931            667086            142721
# 7       KAMAREDDY       277355            996139            166675
# 8      KARIMNAGAR       318562           1029078            212327
# 9         KHAMMAM       466855           1427465            309928
# 10  KOMARAM BHEEM       147606            539579             86829
# 11     MAHABUBABAD      251739            837365            122997
# 12    MAHABUBNAGAR      354405           1588973            261676
# ...

# %%
water_data
# Out:
#          ULB name                                    Source of water  \
# 0        Adilabad                      Sathanala River & Mavala Tank
# 1   Andol-Jogipet            Etigadda,Sathyasai,Vonappuram,Borewells
# 2          Armoor                           surface and ground water
# 3       Atchampet                                         Bore wells
# 4       Badangpet                                 HMWS&SB BORE WELLS
# ..            ...                                                ...
# 67      Vikarabad                           Shivasagar Tank and HMWS
# 68     Wanaparthy                      Ramanpadu Balancing resorvior
# 69       Warangal                                                NaN
# 70       Yellandu  YELLANDULAPADU CHERUVU, KOTILINGALA BORES, 47 ...
# 71     Zaheerabad  Singoor dam back canal river water at itikepal...
#
#     Water Demand (MLD)  Water Treatment facility (MLD)  \
# 0                 0.00                            0.00
# ...

# %% [markdown]
# # Finding the data type

# %%
population_data.dtypes
# Out:
# Districts                   object
# Households                   int64
# Total Population             int64
# Scheduled Castes             int64
# % SC Population              int64
# Scheduled Tribes             int64
# % ST Populaiton              int64
# Backward Castes              int64
# % BC Population              int64
# Others                       int64
# Others %                     int64
# Minorities Population        int64
# Minorities Population %    float64
# dtype: object

# %%
water_data.dtypes
# Out:
# ULB name                                                     object
# Source of water                                              object
# Water Demand (MLD)                                          float64
# Water Treatment facility (MLD)                              float64
# Utilisation of treatment facility                           float64
# Storage Capacity (MLD)                                      float64
# Protected water supply reservoirs                             int64
# Total installed capacity of protected water supply (MGD)      int64
# House service connections (No's)                              int64
# Public stand posts                                            int64
# Length of distribution pipe line (Kms)                      float64
# Area Covered (%)                                              int64
# Water supply through bore wells (MGD)                       float64
# Power bores (No's)                                            int64
# ...
